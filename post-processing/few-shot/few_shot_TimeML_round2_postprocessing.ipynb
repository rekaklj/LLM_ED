# %%
import pandas as pd

# %%
df = pd.read_csv('TimeML_TEST_few_shot_withcommas_round2.csv')
# 'withcommas' means that the csv is comma-separated and not e.g. tab-separated
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...

# %%
def remove_the_beginning(text):
    if 'Annotated sentence:\n\n' in text:
        removebeginning = text.split("Annotated sentence:\n\n", 1)
        removebeginning[0] = ''
        removebeginning = ''.join(removebeginning)
    elif 'Annotated sentence:\n' in text:
        removebeginning = text.split("Annotated sentence:\n", 1)
        removebeginning[0] = ''
        removebeginning = ''.join(removebeginning)
    elif 'New sentence:\n\n' in text:
        removebeginning = text.split("New sentence:\n\n", 1)
        removebeginning[0] = ''
        removebeginning = ''.join(removebeginning)
    else:
        removebeginning = text
    return removebeginning

# %%
df['LLM_response_token_tag_only'] = df['LLM_response'].apply(remove_the_beginning)
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...

# %%
def split_negation(sentence):
    sentence = sentence.replace("couldn't\t<O>\n", "could\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("shouldn't\t<O>\n", "should\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("wouldn't\t<O>\n", "would\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("don't\t<O>\n", "do\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("doesn't\t<O>\n", "does\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("isn't\t<O>\n", "is\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("aren't\t<O>\n", "are\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("didn't\t<O>\n", "did\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("wasn't\t<O>\n", "was\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("weren't\t<O>\n", "were\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("hasn't\t<O>\n", "has\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("haven't\t<O>\n", "have\t<O>\nn't\t<O>\n")
    sentence = sentence.replace("hadn't\t<O>\n", "had\t<O>\nn't\t<O>\n")
    if "\n's\t<O>\n" in sentence:
        sentence = sentence.replace("\n's\t<O>\n", "\n's\t<O>\n")
    else:
        sentence = sentence.replace("'s\t<O>\n", "\t<O>\n's\t<O>\n")
    return sentence

# %%
df['LLM_response_split_negation'] = df['LLM_response_token_tag_only'].apply(split_negation)
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...

# %%
print(df['LLM_response_token_tag_only'][0])
# Out:
# A	<O>
# Cyprus	<O>
# exit	<EVENT>
# from	<O>
# the	<O>
# euro	<O>
# union	<O>
# ,	<O>
# if	<O>
# it	<O>
# comes	<O>
# to	<O>
# that	<O>
# would	<O>
# have	<O>
# a	<O>
# devastating	<EVENT>
# effect	<EVENT>
# on	<O>
# the	<O>
# country's	<O>
# citizens	<O>
# ,	<O>
# who	<O>
# are	<O>
# among	<O>
# the	<O>
# most	<O>
# indebted	<O>
# in	<O>
# the	<O>
# euro	<O>
# zone	<O>
# .	<O>

# %%
print(df['LLM_response_split_negation'][0])
# Out:
# A	<O>
# Cyprus	<O>
# exit	<EVENT>
# from	<O>
# the	<O>
# euro	<O>
# union	<O>
# ,	<O>
# if	<O>
# it	<O>
# comes	<O>
# to	<O>
# that	<O>
# would	<O>
# have	<O>
# a	<O>
# devastating	<EVENT>
# effect	<EVENT>
# on	<O>
# the	<O>
# country	<O>
# 's	<O>
# citizens	<O>
# ,	<O>
# who	<O>
# are	<O>
# among	<O>
# the	<O>
# most	<O>
# indebted	<O>
# in	<O>
# the	<O>
# euro	<O>
# zone	<O>
# .	<O>

# %%
def token_tag(annotated_sentence):
    lines = annotated_sentence.split('\n')
    list_of_token_tag = []
    for line in lines:
        line = line.split()
        if len(line) == 2:
            if 'EVENT' in line[1] or 'O' in line[1]:
                list_of_token_tag.append(line)
                list_of_token_tag
    tuples = []
    for pair in list_of_token_tag:
        tuples.append(tuple(pair))
    return tuple(tuples)  # I am using tuples for further processing, see zip()

# %%
df['list_of_token_tag_pairs'] = df['LLM_response_split_negation'].apply(token_tag)

# %%
(df['list_of_token_tag_pairs'] == ()).sum()
# Out:
# 0

# %%
with open('test_tags_adjusted_TimeML.txt', encoding = 'utf8') as infile:
    gold_TimeML_TEST = infile.read()
print(gold_TimeML_TEST[:100])
# Out:
# A	<O>
# Cyprus	<O>
# exit	<EVENT>
# from	<O>
# the	<O>
# euro	<O>
# union	<O>
# ,	<O>
# if	<O>
# it	<O>
# comes	<EVENT>

# %%
gold_TimeML_TEST = gold_TimeML_TEST.split('\n\n')

# %%
df2 = pd.DataFrame({'gold_TimeML_TEST': gold_TimeML_TEST})
df2
# Out:
#                                       gold_TimeML_TEST
# 0    \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1    And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2    ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3    And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4    Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
# ..                                                 ...
# 270  Memorial\t<O>\nsays\t<EVENT>\ninspectors\t<O>\...
# 271  A\t<O>\nstatement\t<O>\non\t<O>\nthe\t<O>\nMem...
# 272  Memorial\t<O>\ndirector\t<O>\nArseny\t<O>\nRog...
# 273  He\t<O>\ninsisted\t<EVENT>\nthat\t<O>\nthe\t<O...
# 274  ``\t<O>\nWe\t<O>\nwo\t<O>\nn't\t<O>\nrefuse\t<...
#
# [275 rows x 1 columns]

# %%
df['gold_TimeML_TEST'] = df2['gold_TimeML_TEST']
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...

# %%
df['gold_list_of_token_tag_pairs'] = df['gold_TimeML_TEST'].apply(token_tag)
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...

# %%
# remove commas and fullstops from tuple lists to make the postprocessing feasible
def remove_commas_fullstops(tuple_of_tuples):
    list_of_tuples = list(tuple_of_tuples)
    if len(tuple_of_tuples) !=0:
        for item in list_of_tuples:
            list_without_commas_and_fullstops = [item for item in list_of_tuples if item[0] != ',' and item[0] != '.']
        return tuple(list_without_commas_and_fullstops)
    else:
        return tuple_of_tuples
    return

# %%
df['list_of_token_tag_pairs_without_commas_fullstops'] = df['list_of_token_tag_pairs'].apply(remove_commas_fullstops)
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#     list_of_token_tag_pairs_without_commas_fullstops
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...

# %%
df['gold_list_of_token_tag_pairs_without_commas_fullstops'] = df['gold_list_of_token_tag_pairs'].apply(remove_commas_fullstops)
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#     list_of_token_tag_pairs_without_commas_fullstops  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#   gold_list_of_token_tag_pairs_without_commas_fullstops
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...

# %%
equal_length = []
for idx, row in df.iloc[0:].iterrows():
    a=row['list_of_token_tag_pairs']
    b=row['gold_list_of_token_tag_pairs']
    x = len(a) == len(b)
    equal_length.append(x)

# %%
print(equal_length[:50])
# Out:
# [False, True, True, False, False, True, True, True, False, True, True, True, False, True, False, False, True, True, True, True, True, False, False, True, False, True, False, True, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, True, False, True]

# %%
df['equal_length']= pd.DataFrame({
    "equal_length": equal_length
})
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#     list_of_token_tag_pairs_without_commas_fullstops  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#   gold_list_of_token_tag_pairs_without_commas_fullstops  equal_length
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...            False
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...             True
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...             True
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...            False
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...            False

# %%
df['equal_length'].value_counts()
# Out:
# True     154
# False    121
# Name: equal_length, dtype: int64

# %%
#shorter than gold
shorter_than_gold = []
for idx, row in df.iloc[0:].iterrows():
    a=row['list_of_token_tag_pairs']
    b=row['gold_list_of_token_tag_pairs']
    y = len(a) < len(b)
    shorter_than_gold.append(y)

df['shorter_than_gold']= pd.DataFrame({
    "shorter_than_gold": shorter_than_gold
})
df.head()

df['shorter_than_gold'].value_counts()
# Out:
# False    165
# True     110
# Name: shorter_than_gold, dtype: int64

# %%
#longer than gold
longer_than_gold = []
for idx, row in df.iloc[0:].iterrows():
    a=row['list_of_token_tag_pairs']
    b=row['gold_list_of_token_tag_pairs']
    z = len(a) > len(b)
    longer_than_gold.append(z)

df['longer_than_gold']= pd.DataFrame({
    "longer_than_gold": longer_than_gold
})
df.head()

df['longer_than_gold'].value_counts()
# Out:
# False    264
# True      11
# Name: longer_than_gold, dtype: int64

# %%
# equal length without commas and fullstops
equal_length_without_commas_fullstops= []
for idx, row in df.iloc[0:].iterrows():
    a=row['list_of_token_tag_pairs_without_commas_fullstops']
    b=row['gold_list_of_token_tag_pairs_without_commas_fullstops']
    x = len(a) == len(b)
    equal_length_without_commas_fullstops.append(x)

# %%
df['equal_length_without_commas_fullstops']= pd.DataFrame({
    "equal_length_without_commas_fullstops": equal_length_without_commas_fullstops
})
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#     list_of_token_tag_pairs_without_commas_fullstops  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#   gold_list_of_token_tag_pairs_without_commas_fullstops  equal_length  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...            False
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...             True
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...             True
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...            False
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...            False
#
#    shorter_than_gold  longer_than_gold  equal_length_without_commas_fullstops
# 0               True             False                                   True
# 1              False             False                                   True
# 2              False             False                                   True
# 3               True             False                                   True
# 4              False              True                                  False

# %%
df['equal_length_without_commas_fullstops'].value_counts()
# Out:
# True     224
# False     51
# Name: equal_length_without_commas_fullstops, dtype: int64

# %%
complete_dataset_for_eval= []
for idx, row in df.iloc[0:].iterrows():
    a=row['equal_length_without_commas_fullstops']
    b=row['LLM_response_split_negation']
    c=row['gold_TimeML_TEST']
    if a == True:
        complete_dataset_for_eval.append(b)
    else:
        complete_dataset_for_eval.append(c)

df['complete_dataset_for_eval'] = complete_dataset_for_eval

# %%
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#     list_of_token_tag_pairs_without_commas_fullstops  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#   gold_list_of_token_tag_pairs_without_commas_fullstops  equal_length  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...            False
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...             True
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...             True
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...            False
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...            False
#
#    shorter_than_gold  longer_than_gold  equal_length_without_commas_fullstops  \
# 0               True             False                                   True
# 1              False             False                                   True
# 2              False             False                                   True
# 3               True             False                                   True
# 4              False              True                                  False
#
#                            complete_dataset_for_eval
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...

# %%
# where equal_length_without_commas_fullstops is False, change EVENT to O
complete_dataset_for_eval_adjusted= []
for idx, row in df.iloc[0:].iterrows():
    a=row['equal_length_without_commas_fullstops']
    b=row['complete_dataset_for_eval']
    if a == False:
        o_tags = b.replace("<EVENT>", "<O>")
        complete_dataset_for_eval_adjusted.append(o_tags)
    else:
        complete_dataset_for_eval_adjusted.append(b)

df['complete_dataset_for_eval_adjusted'] = complete_dataset_for_eval_adjusted
df.head(2)
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
#
#     list_of_token_tag_pairs_without_commas_fullstops  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
#
#   gold_list_of_token_tag_pairs_without_commas_fullstops  equal_length  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...            False
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...             True
#
#    shorter_than_gold  longer_than_gold  equal_length_without_commas_fullstops  \
# 0               True             False                                   True
# 1              False             False                                   True
#
#                            complete_dataset_for_eval  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
#
#                   complete_dataset_for_eval_adjusted
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...

# %%
df.shape
# Out:
# (275, 17)

# %%
# list of token tag pairs
df['for_eval_token_tag_pairs'] = df['complete_dataset_for_eval_adjusted'].apply(token_tag)

# %%
# remove commas and fullstops
df['for_eval_token_tag_pairs_without_commas_fullstops'] = df['for_eval_token_tag_pairs'].apply(remove_commas_fullstops)
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0   A Cyprus exit from the euro union, if it come...
# 1           1  And for European unity and diplomacy, the Cypr...
# 2           2  ut for the broader financial system in Europe,...
# 3           3  And that, economists and investors contend, is...
# 4           4  Greece may well have been too big to fail last...
#
#                                               prompt  \
# 0  Here are four correct examples for annotating ...
# 1  Here are four correct examples for annotating ...
# 2  Here are four correct examples for annotating ...
# 3  Here are four correct examples for annotating ...
# 4  Here are four correct examples for annotating ...
#
#                                         LLM_response  \
# 0  Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1  Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2  Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3  Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4  Sentence:\nGreece may well have been too big t...
#
#                          LLM_response_token_tag_only  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                          LLM_response_split_negation  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                              list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#                                     gold_TimeML_TEST  \
# 0  \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                         gold_list_of_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#     list_of_token_tag_pairs_without_commas_fullstops  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#   gold_list_of_token_tag_pairs_without_commas_fullstops  equal_length  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...            False
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...             True
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...             True
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...            False
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...            False
#
#    shorter_than_gold  longer_than_gold  equal_length_without_commas_fullstops  \
# 0               True             False                                   True
# 1              False             False                                   True
# 2              False             False                                   True
# 3               True             False                                   True
# 4              False              True                                  False
#
#                            complete_dataset_for_eval  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                   complete_dataset_for_eval_adjusted  \
# 0  A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1  And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2  ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3  And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4  Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
#
#                             for_eval_token_tag_pairs  \
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...
#
#    for_eval_token_tag_pairs_without_commas_fullstops
# 0  ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1  ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2  ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3  ((And, <O>), (that, <O>), (economists, <O>), (...
# 4  ((Greece, <O>), (may, <O>), (well, <O>), (have...

# %%
# equal length without commas and fullstops
equal_length_without_commas_fullstops= []
for idx, row in df.iloc[0:].iterrows():
    a=row['for_eval_token_tag_pairs_without_commas_fullstops']
    b=row['gold_list_of_token_tag_pairs_without_commas_fullstops']
    x = len(a) == len(b)
    equal_length_without_commas_fullstops.append(x)

# %%
# check equal length maybe one more time
equal_length_without_commas_fullstops.count(True)
# Out:
# 275

# %%
equal_length_without_commas_fullstops.count(False)
# Out:
# 0

# %%
zippedlines = []
for idx, row in df.iloc[0:].iterrows():    
    a=row['for_eval_token_tag_pairs_without_commas_fullstops']
    b=row['gold_list_of_token_tag_pairs_without_commas_fullstops']
    a= list(a)
    b= list(b)
    zippedlines.append(list(zip(b, a)))

# %%
df['zippedlines']= pd.DataFrame({
    "zippedlines": zippedlines
})
df
# Out:
#      Unnamed: 0                                           sentence  \
# 0             0   A Cyprus exit from the euro union, if it come...
# 1             1  And for European unity and diplomacy, the Cypr...
# 2             2  ut for the broader financial system in Europe,...
# 3             3  And that, economists and investors contend, is...
# 4             4  Greece may well have been too big to fail last...
# ..          ...                                                ...
# 270         270  Memorial says inspectors returned to its Mosco...
# 271         271  A statement on the Memorial website said the i...
# 272         272  Memorial director Arseny Roginsky, quoted by t...
# 273         273  He insisted that the NGO law `` will not chang...
# 274         274  `` We won't refuse foreign donations, nor will...
#
#                                                 prompt  \
# 0    Here are four correct examples for annotating ...
# 1    Here are four correct examples for annotating ...
# 2    Here are four correct examples for annotating ...
# 3    Here are four correct examples for annotating ...
# 4    Here are four correct examples for annotating ...
# ..                                                 ...
# 270  Here are four correct examples for annotating ...
# 271  Here are four correct examples for annotating ...
# 272  Here are four correct examples for annotating ...
# 273  Here are four correct examples for annotating ...
# 274  Here are four correct examples for annotating ...
#
#                                           LLM_response  \
# 0    Annotated sentence:\n\nA\t<O>\nCyprus\t<O>\nex...
# 1    Annotated sentence:\n\nAnd\t<O>\nfor\t<O>\nEur...
# 2    Annotated sentence:\n\nut\t<O>\nfor\t<O>\nthe\...
# 3    Annotated sentence:\n\nAnd\t<O>\nthat\t<O>\nec...
# 4    Sentence:\nGreece may well have been too big t...
# ..                                                 ...
# 270  Annotated sentence:\n\nMemorial\t<O>\nsays\t<E...
# 271  Sentence:\nA statement on the Memorial website...
# 272  Annotated sentence:\n\nMemorial\t<O>\ndirector...
# 273  Example5\n\nSentence:\nHe insisted that the NG...
# 274  New sentence:\nWe won't refuse foreign donatio...
#
#                            LLM_response_token_tag_only  \
# 0    A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1    And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2    ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3    And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4    Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
# ..                                                 ...
# 270  Memorial\t<O>\nsays\t<EVENT>\ninspectors\t<O>\...
# 271  A\t<O>\nstatement\t<O>\non\t<O>\nthe\t<O>\nMem...
# 272  Memorial\t<O>\ndirector\t<O>\nArseny\t<O>\nRog...
# 273  He\t<O>\ninsisted\t<EVENT>\nthat\t<O>\nthe\t<O...
# 274  We\t<O>\nwon't\t<O>\nrefuse\t<O>\nforeign\t<O>...
#
#                            LLM_response_split_negation  \
# 0    A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1    And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2    ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3    And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4    Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
# ..                                                 ...
# 270  Memorial\t<O>\nsays\t<EVENT>\ninspectors\t<O>\...
# 271  A\t<O>\nstatement\t<O>\non\t<O>\nthe\t<O>\nMem...
# 272  Memorial\t<O>\ndirector\t<O>\nArseny\t<O>\nRog...
# 273  He\t<O>\ninsisted\t<EVENT>\nthat\t<O>\nthe\t<O...
# 274  We\t<O>\nwon't\t<O>\nrefuse\t<O>\nforeign\t<O>...
#
#                                list_of_token_tag_pairs  \
# 0    ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1    ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2    ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3    ((And, <O>), (that, <O>), (economists, <O>), (...
# 4    ((Greece, <O>), (may, <O>), (well, <O>), (have...
# ..                                                 ...
# 270  ((Memorial, <O>), (says, <EVENT>), (inspectors...
# 271  ((A, <O>), (statement, <O>), (on, <O>), (the, ...
# 272  ((Memorial, <O>), (director, <O>), (Arseny, <O...
# 273  ((He, <O>), (insisted, <EVENT>), (that, <O>), ...
# 274  ((We, <O>), (won't, <O>), (refuse, <O>), (fore...
#
#                                       gold_TimeML_TEST  \
# 0    \nA\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O...
# 1    And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2    ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3    And\t<O>\nthat\t<O>\n,\t<O>\neconomists\t<O>\n...
# 4    Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
# ..                                                 ...
# 270  Memorial\t<O>\nsays\t<EVENT>\ninspectors\t<O>\...
# 271  A\t<O>\nstatement\t<O>\non\t<O>\nthe\t<O>\nMem...
# 272  Memorial\t<O>\ndirector\t<O>\nArseny\t<O>\nRog...
# 273  He\t<O>\ninsisted\t<EVENT>\nthat\t<O>\nthe\t<O...
# 274  ``\t<O>\nWe\t<O>\nwo\t<O>\nn't\t<O>\nrefuse\t<...
#
#                           gold_list_of_token_tag_pairs  \
# 0    ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1    ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2    ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3    ((And, <O>), (that, <O>), (,, <O>), (economist...
# 4    ((Greece, <O>), (may, <O>), (well, <O>), (have...
# ..                                                 ...
# 270  ((Memorial, <O>), (says, <EVENT>), (inspectors...
# 271  ((A, <O>), (statement, <O>), (on, <O>), (the, ...
# 272  ((Memorial, <O>), (director, <O>), (Arseny, <O...
# 273  ((He, <O>), (insisted, <EVENT>), (that, <O>), ...
# 274  ((``, <O>), (We, <O>), (wo, <O>), (n't, <O>), ...
#
#       list_of_token_tag_pairs_without_commas_fullstops  \
# 0    ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1    ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2    ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3    ((And, <O>), (that, <O>), (economists, <O>), (...
# 4    ((Greece, <O>), (may, <O>), (well, <O>), (have...
# ..                                                 ...
# 270  ((Memorial, <O>), (says, <EVENT>), (inspectors...
# 271  ((A, <O>), (statement, <O>), (on, <O>), (the, ...
# 272  ((Memorial, <O>), (director, <O>), (Arseny, <O...
# 273  ((He, <O>), (insisted, <EVENT>), (that, <O>), ...
# 274  ((We, <O>), (won't, <O>), (refuse, <O>), (fore...
#
#     gold_list_of_token_tag_pairs_without_commas_fullstops  equal_length  \
# 0    ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...            False
# 1    ((And, <O>), (for, <O>), (European, <O>), (uni...             True
# 2    ((ut, <O>), (for, <O>), (the, <O>), (broader, ...             True
# 3    ((And, <O>), (that, <O>), (economists, <O>), (...            False
# 4    ((Greece, <O>), (may, <O>), (well, <O>), (have...            False
# ..                                                 ...              ...
# 270  ((Memorial, <O>), (says, <EVENT>), (inspectors...             True
# 271  ((A, <O>), (statement, <O>), (on, <O>), (the, ...            False
# 272  ((Memorial, <O>), (director, <O>), (Arseny, <O...             True
# 273  ((He, <O>), (insisted, <EVENT>), (that, <O>), ...            False
# 274  ((``, <O>), (We, <O>), (wo, <O>), (n't, <O>), ...            False
#
#      shorter_than_gold  longer_than_gold  \
# 0                 True             False
# 1                False             False
# 2                False             False
# 3                 True             False
# 4                False              True
# ..                 ...               ...
# 270              False             False
# 271               True             False
# 272              False             False
# 273               True             False
# 274               True             False
#
#      equal_length_without_commas_fullstops  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                    False
# ..                                     ...
# 270                                   True
# 271                                   True
# 272                                  False
# 273                                   True
# 274                                  False
#
#                              complete_dataset_for_eval  \
# 0    A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1    And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2    ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3    And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4    Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
# ..                                                 ...
# 270  Memorial\t<O>\nsays\t<EVENT>\ninspectors\t<O>\...
# 271  A\t<O>\nstatement\t<O>\non\t<O>\nthe\t<O>\nMem...
# 272  Memorial\t<O>\ndirector\t<O>\nArseny\t<O>\nRog...
# 273  He\t<O>\ninsisted\t<EVENT>\nthat\t<O>\nthe\t<O...
# 274  ``\t<O>\nWe\t<O>\nwo\t<O>\nn't\t<O>\nrefuse\t<...
#
#                     complete_dataset_for_eval_adjusted  \
# 0    A\t<O>\nCyprus\t<O>\nexit\t<EVENT>\nfrom\t<O>\...
# 1    And\t<O>\nfor\t<O>\nEuropean\t<O>\nunity\t<O>\...
# 2    ut\t<O>\nfor\t<O>\nthe\t<O>\nbroader\t<O>\nfin...
# 3    And\t<O>\nthat\t<O>\neconomists\t<O>\nand\t<O>...
# 4    Greece\t<O>\nmay\t<O>\nwell\t<O>\nhave\t<O>\nb...
# ..                                                 ...
# 270  Memorial\t<O>\nsays\t<EVENT>\ninspectors\t<O>\...
# 271  A\t<O>\nstatement\t<O>\non\t<O>\nthe\t<O>\nMem...
# 272  Memorial\t<O>\ndirector\t<O>\nArseny\t<O>\nRog...
# 273  He\t<O>\ninsisted\t<EVENT>\nthat\t<O>\nthe\t<O...
# 274  ``\t<O>\nWe\t<O>\nwo\t<O>\nn't\t<O>\nrefuse\t<...
#
#                               for_eval_token_tag_pairs  \
# 0    ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1    ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2    ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3    ((And, <O>), (that, <O>), (economists, <O>), (...
# 4    ((Greece, <O>), (may, <O>), (well, <O>), (have...
# ..                                                 ...
# 270  ((Memorial, <O>), (says, <EVENT>), (inspectors...
# 271  ((A, <O>), (statement, <O>), (on, <O>), (the, ...
# 272  ((Memorial, <O>), (director, <O>), (Arseny, <O...
# 273  ((He, <O>), (insisted, <EVENT>), (that, <O>), ...
# 274  ((``, <O>), (We, <O>), (wo, <O>), (n't, <O>), ...
#
#      for_eval_token_tag_pairs_without_commas_fullstops  \
# 0    ((A, <O>), (Cyprus, <O>), (exit, <EVENT>), (fr...
# 1    ((And, <O>), (for, <O>), (European, <O>), (uni...
# 2    ((ut, <O>), (for, <O>), (the, <O>), (broader, ...
# 3    ((And, <O>), (that, <O>), (economists, <O>), (...
# 4    ((Greece, <O>), (may, <O>), (well, <O>), (have...
# ..                                                 ...
# 270  ((Memorial, <O>), (says, <EVENT>), (inspectors...
# 271  ((A, <O>), (statement, <O>), (on, <O>), (the, ...
# 272  ((Memorial, <O>), (director, <O>), (Arseny, <O...
# 273  ((He, <O>), (insisted, <EVENT>), (that, <O>), ...
# 274  ((``, <O>), (We, <O>), (wo, <O>), (n't, <O>), ...
#
#                                            zippedlines
# 0    [((A, <O>), (A, <O>)), ((Cyprus, <O>), (Cyprus...
# 1    [((And, <O>), (And, <O>)), ((for, <O>), (for, ...
# 2    [((ut, <O>), (ut, <O>)), ((for, <O>), (for, <O...
# 3    [((And, <O>), (And, <O>)), ((that, <O>), (that...
# 4    [((Greece, <O>), (Greece, <O>)), ((may, <O>), ...
# ..                                                 ...
# 270  [((Memorial, <O>), (Memorial, <O>)), ((says, <...
# 271  [((A, <O>), (A, <O>)), ((statement, <O>), (sta...
# 272  [((Memorial, <O>), (Memorial, <O>)), ((directo...
# 273  [((He, <O>), (He, <O>)), ((insisted, <EVENT>),...
# 274  [((``, <O>), (``, <O>)), ((We, <O>), (We, <O>)...
#
# [275 rows x 20 columns]

# %%
df['zippedlines'][0]
# Out:
# [(('A', '<O>'), ('A', '<O>')),
#  (('Cyprus', '<O>'), ('Cyprus', '<O>')),
#  (('exit', '<EVENT>'), ('exit', '<EVENT>')),
#  (('from', '<O>'), ('from', '<O>')),
#  (('the', '<O>'), ('the', '<O>')),
#  (('euro', '<O>'), ('euro', '<O>')),
#  (('union', '<O>'), ('union', '<O>')),
#  (('if', '<O>'), ('if', '<O>')),
#  (('it', '<O>'), ('it', '<O>')),
#  (('comes', '<EVENT>'), ('comes', '<O>')),
#  (('to', '<O>'), ('to', '<O>')),
#  (('that', '<O>'), ('that', '<O>')),
#  (('would', '<O>'), ('would', '<O>')),
#  (('have', '<O>'), ('have', '<O>')),
#  (('a', '<O>'), ('a', '<O>')),
#  (('devastating', '<O>'), ('devastating', '<EVENT>')),
#  (('effect', '<EVENT>'), ('effect', '<EVENT>')),
#  (('on', '<O>'), ('on', '<O>')),
#  (('the', '<O>'), ('the', '<O>')),
#  (('country', '<O>'), ('country', '<O>')),
#  (("'s", '<O>'), ("'s", '<O>')),
#  (('citizens', '<O>'), ('citizens', '<O>')),
#  (('who', '<O>'), ('who', '<O>')),
#  (('are', '<O>'), ('are', '<O>')),
#  (('among', '<O>'), ('among', '<O>')),
#  (('the', '<O>'), ('the', '<O>')),
#  (('most', '<O>'), ('most', '<O>')),
#  (('indebted', '<EVENT>'), ('indebted', '<O>')),
#  (('in', '<O>'), ('in', '<O>')),
#  (('the', '<O>'), ('the', '<O>')),
#  (('euro', '<O>'), ('euro', '<O>')),
#  (('zone', '<O>'), ('zone', '<O>'))]

# %%
def zips(tuples):
    lines = []
    for item in tuples:
        lines.append(f'{id(item)}\t{item[0][0]}\t{item[0][1]}\t{item[1][0]}\t{item[1][1]}\n')
    return ''.join(lines)

# %%
for idx, row in df.iloc[0:].iterrows():    
    a=row['zippedlines']
    a= zips(a)
    with open('TimeML_few_shot_gold_predicted_1706.txt', 'a', encoding='utf8') as outfile:
        outfile.write(f'{a}\n')

# %%
with open('TimeML_few_shot_gold_predicted_1706.txt', encoding='utf8') as infile:
    text = infile.read()

# %%
print(text[:2000])
# Out:
# 2142671673984	A	<O>	A	<O>
# 2142671790080	Cyprus	<O>	Cyprus	<O>
# 2142670346304	exit	<EVENT>	exit	<EVENT>
# 2142671785664	from	<O>	from	<O>
# 2142671784832	the	<O>	the	<O>
# 2142671784576	euro	<O>	euro	<O>
# 2142671784704	union	<O>	union	<O>
# 2142671785344	if	<O>	if	<O>
# 2142671784192	it	<O>	it	<O>
# 2142671783104	comes	<EVENT>	comes	<O>
# 2142671682176	to	<O>	to	<O>
# 2142671782080	that	<O>	that	<O>
# 2142671207360	would	<O>	would	<O>
# 2142671784512	have	<O>	have	<O>
# 2142671783296	a	<O>	a	<O>
# 2142670244352	devastating	<O>	devastating	<EVENT>
# 2142634322048	effect	<EVENT>	effect	<EVENT>
# 2142671681984	on	<O>	on	<O>
# 2142671683136	the	<O>	the	<O>
# 2142670665536	country	<O>	country	<O>
# 2142670254016	's	<O>	's	<O>
# 2142650166528	citizens	<O>	citizens	<O>
# 2142671682944	who	<O>	who	<O>
# 2142671682816	are	<O>	are	<O>
# 2142671681664	among	<O>	among	<O>
# 2142671683392	the	<O>	the	<O>
# 2142671683200	most	<O>	most	<O>
# 2142671788544	indebted	<EVENT>	indebted	<O>
# 2142670268736	in	<O>	in	<O>
# 2142671682752	the	<O>	the	<O>
# 2142670263296	euro	<O>	euro	<O>
# 2142671682368	zone	<O>	zone	<O>
#
# 2142671682880	And	<O>	And	<O>
# 2142671680960	for	<O>	for	<O>
# 2142671784064	European	<O>	European	<O>
# 2142671673920	unity	<O>	unity	<O>
# 2142671676096	and	<O>	and	<O>
# 2142671678464	diplomacy	<O>	diplomacy	<O>
# 2142671679808	the	<O>	the	<O>
# 2142671676928	Cyprus	<O>	Cyprus	<O>
# 2142671679680	debacle	<EVENT>	debacle	<EVENT>
# 2142671678592	has	<O>	has	<EVENT>
# 2142671677376	already	<O>	already	<O>
# 2142671676608	been	<O>	been	<O>
# 2142670252864	at	<O>	at	<O>
# 2142670208640	least	<O>	least	<O>
# 2142670242752	a	<O>	a	<O>
# 2142671679424	short-term	<O>	short-term	<O>
# 2142671681920	disaster	<EVENT>	disaster	<EVENT>
#
# 2142671681536	ut	<O>	ut	<O>
# 2142670265728	for	<O>	for	<O>
# 2142671682112	the	<O>	the	<O>
# 2142671681408	broader	<O>	broader	<O>
# 2142623285440	financial	<O>	financial	<O>
# 2142671682048	system	<O>	system	<O>
# 2142670272192	in	<O>	in	<O>
# 2142670272064	Europe	<O>	Europe	<O>
# 2142629526656	the	<O>	the	<O>
# 2142670270848	losses	<O>	losses	<O>
# 214267

# %%
text = text.split('\n')

# %%
lines = []
for item in text:
    line = item.split()
    lines.append(line)
    
print(lines[:20])
# Out:
# [['2142671673984', 'A', '<O>', 'A', '<O>'], ['2142671790080', 'Cyprus', '<O>', 'Cyprus', '<O>'], ['2142670346304', 'exit', '<EVENT>', 'exit', '<EVENT>'], ['2142671785664', 'from', '<O>', 'from', '<O>'], ['2142671784832', 'the', '<O>', 'the', '<O>'], ['2142671784576', 'euro', '<O>', 'euro', '<O>'], ['2142671784704', 'union', '<O>', 'union', '<O>'], ['2142671785344', 'if', '<O>', 'if', '<O>'], ['2142671784192', 'it', '<O>', 'it', '<O>'], ['2142671783104', 'comes', '<EVENT>', 'comes', '<O>'], ['2142671682176', 'to', '<O>', 'to', '<O>'], ['2142671782080', 'that', '<O>', 'that', '<O>'], ['2142671207360', 'would', '<O>', 'would', '<O>'], ['2142671784512', 'have', '<O>', 'have', '<O>'], ['2142671783296', 'a', '<O>', 'a', '<O>'], ['2142670244352', 'devastating', '<O>', 'devastating', '<EVENT>'], ['2142634322048', 'effect', '<EVENT>', 'effect', '<EVENT>'], ['2142671681984', 'on', '<O>', 'on', '<O>'], ['2142671683136', 'the', '<O>', 'the', '<O>'], ['2142670665536', 'country', '<O>', 'country', '<O>']]

# %%
ids = []
for line in lines:
    if len(line) ==5 and line[1] != line[3]:
        ids.append([line[0], line[1], line[3]])
    ids
    
print(ids)
# Out:
# [['2142671791232', '-LRB-', '-'], ['2142671827648', '-LRB-', '-'], ['2142671827712', 'title', 'LRB-'], ['2142671827776', 'body', 'title'], ['2142671827840', 'etc.', 'body'], ['2142671857024', 'Corp.', 'Corp'], ['2142671906240', '``', 'He'], ['2142671904512', 'He', 'would'], ['2142671904704', 'would', 'like'], ['2142671904640', 'like', 'to'], ['2142671906368', 'to', 'straighten'], ['2142671906176', 'straighten', 'things'], ['2142671906304', 'things', 'out'], ['2142671906432', 'out', 'with'], ['2142671906496', 'with', '-'], ['2142671904576', '-LRB-', 'LRB-'], ['2142671906624', '-RRB-', '-'], ['2142671906688', 'when', 'RRB-'], ['2142671906752', 'the', 'when'], ['2142671906816', 'time', 'the'], ['2142671906880', 'comes', 'time'], ['2142671906944', "''", 'comes'], ['2142672160640', "''", "''."], ['2142672206656', '28', '28,'], ['2142672222080', "''", "''."]]

# %%
len(ids)
# Out:
# 25

# %%
for item in ids:
    print(f'{item[0]}\t{item[1]}\t{item[2]}')
# Out:
# 2142671791232	-LRB-	-
# 2142671827648	-LRB-	-
# 2142671827712	title	LRB-
# 2142671827776	body	title
# 2142671827840	etc.	body
# 2142671857024	Corp.	Corp
# 2142671906240	``	He
# 2142671904512	He	would
# 2142671904704	would	like
# 2142671904640	like	to
# 2142671906368	to	straighten
# 2142671906176	straighten	things
# 2142671906304	things	out
# 2142671906432	out	with
# 2142671906496	with	-
# 2142671904576	-LRB-	LRB-
# 2142671906624	-RRB-	-
# 2142671906688	when	RRB-
# 2142671906752	the	when
# 2142671906816	time	the
# 2142671906880	comes	time
# 2142671906944	''	comes
# 2142672160640	''	''.
# 2142672206656	28	28,
# 2142672222080	''	''.
